# %%
# %matplotlib inline
import numpy as np
from nicks_plot_utils import Hist1D, Hist2D
import matplotlib.pyplot as plt
import pandas as pd
from lmfit.models import *

# %%
mu = 0.0
sigma = 0.2
num = 1_000_000

data = pd.DataFrame({'x' : np.random.normal(mu, sigma, num),
                     'y' : np.random.normal(mu+0.2, sigma, num),
                     'z' : np.random.normal(mu-0.5, 0.5, num)})

# %%
fig, ax = plt.subplots(figsize=(12,9))
testHist = Hist2D(x_left=-2.0, x_right=2.0, x_bins=250, y_left=-2.0, y_right=2.0, y_bins=250)
testHist.fill(data.x, data.z)
testHist.plot()
testHist.fitGausian(label=True)
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>103</td><td></td></tr><tr><td># data points</td><td>62500</td><td></td></tr><tr><td># variables</td><td>6</td><td></td></tr><tr><td>chi-square</td><td> 15.6447345</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.5034e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-518287.214</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-518232.957</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> height </td><td>  1.59686962 </td><td>  6.3972e-04 </td><td> (0.04%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> cen_x </td><td>  0.00809808 </td><td>  8.0023e-05 </td><td> (0.99%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True <
# ...

# %%
df = pd.read_csv("/Users/tylern/Data/momCorr.csv")
df.head()
# Out:
#         e_p   e_theta     e_phi       p_p   p_theta     p_phi  W_uncorr  \
# 0  1.830707  0.508287  1.295685  0.000000  1.570796  0.000000  2.062753
# 1  2.091671  0.409377  2.757419  2.308409  0.430126 -0.442297  2.080827
# 2  0.608885  0.716795  1.476836  0.000000  1.570796  0.000000  2.708126
# 3  2.086218  0.411051 -1.564494  0.804731  0.522632  1.641332  2.081104
# 4  1.583370  0.586388 -0.819540  0.000000  1.570796  0.000000  2.097729
#
#    Q2_uncorr  sector  type
# 0   2.229802       1  none
# 1   1.665202       6  none
# 2   1.443611       1  none
# 3   1.674281       4  none
# 4   2.548427       3  none

# %%
fig, ax = plt.subplots(figsize=(12,9))
testHist = Hist2D(x_left=0, x_right=3.0, x_bins=500, y_left=1.0, y_right=2.0, y_bins=500)
testHist.fill(df.W_uncorr, df.Q2_uncorr)
testHist.plot()
