# %%
# %matplotlib inline
import numpy as np
from nicks_plot_utils import Hist1D, Hist2D
import matplotlib.pyplot as plt
import pandas as pd
from lmfit.models import *

# %%
mu = 0.0
sigma = 0.2
num = 100_000

data = pd.DataFrame({'W' : np.random.normal(mu, sigma, num),
                     'y' : np.random.normal(mu+0.2, sigma, num),
                     'z' : np.random.normal(mu-0.5, 0.5, num),})

# %%
testHist = Hist1D(left=-2.0, right=2.0, bins=250, name='W $[GeV]$')

testHist.fill(data.W)
testHist.fill(data.z)
# Out:
# Hist1D(Regular(250, -2, 2), storage=Double()) # Sum: 199864.0 (200000.0 with flow)

# %%
testHist2 = Hist1D(left=-2.0, right=2.0, bins=250)
testHist2.fill(data.y)
# Out:
# Hist1D(Regular(250, -2, 2), storage=Double()) # Sum: 100000.0

# %%
fig, ax = plt.subplots(figsize=(12,9))
testHist.histogram(ax, filled=True)


gauss1 = GaussianModel(prefix='g1_')
pars = gauss1.make_params()

pars['g1_center'].set(value=0.0)
pars['g1_sigma'].set(value=0.2)


gauss2 = GaussianModel(prefix='g2_')
pars.update(gauss2.make_params())

pars['g2_center'].set(value=-0.3)
pars['g2_sigma'].set(value=0.5)


mod = gauss1 + gauss2


testHist.customModel(mod, params=pars)
# Out:
# <h2> Model</h2> (Model(gaussian, prefix='g1_') + Model(gaussian, prefix='g2_')) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>43</td><td></td></tr><tr><td># data points</td><td>250</td><td></td></tr><tr><td># variables</td><td>6</td><td></td></tr><tr><td>chi-square</td><td> 0.01172252</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.8043e-05</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2479.92616</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2458.79739</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> g1_amplitude </td><td>  0.40513235 </td><td>  0.00390215 </td><td> (0.96%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g1_center </td><td>  0.00165215 </td><td>  6.3098e-04 </td><td> (38.19%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g1_sigma </td><td>  0.20057115 </td><td>  0.00100750 </td><td> (0.50%) </td><td> 0.2 </td><td>  0.00000000 </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g1_fwhm </td><td>  0.47230896 </td><td>  0.00237247 </td><td> (0.50%) </td><td> 0.47096400000000005 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 2.3548200*g1_sigma </td></tr><tr><td> g1_height </td><td>  0.80582094 </td><td>  0.00449318 </td><td> (0.56%) </td><td> 1.9947115 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 0.3989423*g1_amplitude/max(2.220446049250313e-16, g1_sigma) </td></tr><tr><td> g2_amplitude </td><td>  0.40282775 </td><td>  0.00452752 </td><td> (1.12%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g2_center </td><td> -0.50375755 </td><td>  0.00648743 </td><td> (1.29%) </td><td> -0.3 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g2_sigma </td><td>  0.49928724 </td><td>  0.00351828 </td><td> (0.70%) </td><td> 0.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g2_fwhm </td><td>  1.17573158 </td><td>  0.00828492 </td><td> (0.70%) </td><td> 1.17741 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 2.3548200*g2_sigma </td></tr><tr><td> g2_height </td><td>  0.32186889 </td><td>  0.00224468 </td><td> (0.70%) </td><td> 0.7978846 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 0.3989423*g2_amplitude/max(2.220446049250313e-16, g2_sigma) </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>g1_amplitude</td><td>g2_amplitude</td><td>-0.9478</td></tr><tr><td>g1_amplitude</td><td>g2_center</td><td>-0.9458</td></tr><tr><td>g2_amplitude</td><td>g2_center</td><td>0.8997</td></tr><tr><td>g1_amplitude</td><td>g1_sigma</td><td>0.8982</td></tr><tr><td>g1_sigma</td><td>g2_amplitude</td><td>-0.8348</td></tr><tr><td>g1_sigma</td><td>g2_center</td><td>-0.8162</td></tr><tr><td>g2_amplitude</td><td>g2_sigma</td><td>0.8039</td></tr><tr><td>g1_amplitude</td><td>g2_sigma</td><td>-0.7208</td></tr><tr><td>g2_center</td><td>g2_sigma</td><td>0.6981</td></tr><tr><td>g1_sigma</td><td>g2_sigma</td><td>-0.5856</td></tr><tr><td>g1_center</td><td>g2_sigma</td><td>-0.3654</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(12,9))
testHist2.errorbar()
# testHist2.fitBreitWigner()
# testHist2.fitSplitLorentzian()
testHist2.fitDonaich()
# testHist2.fitSkewedVoigt()
# Out:
# <h2> Model</h2> Model(doniach) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>64</td><td></td></tr><tr><td># data points</td><td>250</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 0.44859562</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.00182356</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1572.77358</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1558.68774</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> amplitude </td><td>  0.19876178 </td><td>  0.00269612 </td><td> (1.36%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> center </td><td>  0.17748191 </td><td>  0.00346213 </td><td> (1.95%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> sigma </td><td>  0.20731907 </td><td>  0.00464935 </td><td> (2.24%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> gamma </td><td> -0.06928994 </td><td>  0.00799751 </td><td> (11.54%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> height </td><td>  1.06283581 </td><td>  0.01400774 </td><td> (1.32%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> False </td><td> amplitude/max(2.220446049250313e-16, (sigma**(1-gamma)))*cos(pi*gamma/2) </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>center</td><td>gamma</td><td>0.7038</td></tr><tr><td>sigma</td><td>gamma</td><td>-0.6324</td></tr><tr><td>amplitude</td><td>sigma</td><td>0.5837</td></tr><tr><td>center</td><td>sigma</td><td>-0.4450</td></tr></table>

# %%
testHist3 = Hist2D(x_left=-2.0, x_right=2.0, x_bins=250, y_left=-2.0, y_right=2.0, y_bins=250)
testHist3.fill(data.W, data.z)
testHist3.plot()
testHist3.fitGausian()
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>59</td><td></td></tr><tr><td># data points</td><td>62500</td><td></td></tr><tr><td># variables</td><td>6</td><td></td></tr><tr><td>chi-square</td><td> 153.017974</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.00244852</td><td></td></tr><tr><td>Akaike info crit.</td><td>-375760.903</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-375706.645</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> height </td><td>  1.58943861 </td><td>  0.00199393 </td><td> (0.13%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> centroid_x </td><td> -0.49302731 </td><td>  6.2741e-04 </td><td> (0.13%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> centroid_y </td><td>  0.00942200 </td><td>  2.5179e-04 </td><td> (2.67%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> sigma_x </td><td>  0.50018550 </td><td>  6.4171e-04 </td><td> (0.13%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> sigma_y </td><td> -0.20075031 </td><td>  2.5758e-04 </td><td> (0.13%) </td><td> 3.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> background </td><td> -5.6025e-05 </td><td>  1.3549e-04 </td><td> (241.84%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>height</td><td>sigma_x</td><td>-0.4890</td></tr><tr><td>height</td><td>sigma_y</td><td>0.4881</td></tr><tr><td>sigma_y</td><td>background</td><td>0.2112</td></tr><tr><td>sigma_x</td><td>background</td><td>-0.2060</td></tr></table>
