# %%
# %matplotlib inline
import numpy as np
from nicks_plot_utils import Hist1D
import matplotlib.pyplot as plt
import pandas as pd
from lmfit.models import *

# %%
mu = 0.0
sigma = 0.2
num = 100_000

data = pd.DataFrame({'W' : np.random.normal(mu, sigma, num),
                     'y' : np.random.normal(mu+0.2, sigma, num),
                     'z' : np.random.normal(mu-0.5, sigma, num),})

# %%
testHist = Hist1D(left=-2.0, right=2.0, bins=250, name='W $[GeV]$')

testHist.fill(data.W)
testHist.fill(data.z)
# Out:
# Hist1D(Regular(250, -2, 2), storage=Double()) # Sum: 200000.0

# %%
testHist2 = Hist1D(left=-2.0, right=2.0, bins=250)
testHist2.fill(data.y)
# Out:
# Hist1D(Regular(250, -2, 2), storage=Double()) # Sum: 100000.0

# %%
fig, ax = plt.subplots(figsize=(12,9))
testHist.histogram(ax, filled=True)


gauss1 = GaussianModel(prefix='g1_')
pars = gauss1.make_params()

pars['g1_center'].set(value=0.0)
pars['g1_sigma'].set(value=0.2)


gauss2 = GaussianModel(prefix='g2_')
pars.update(gauss2.make_params())

pars['g2_center'].set(value=-0.3)
pars['g2_sigma'].set(value=0.2)


mod = gauss1 + gauss2


testHist.customModel(mod, params=pars)
# Out:
# <h2> Model</h2> (Model(gaussian, prefix='g1_') + Model(gaussian, prefix='g2_')) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>95</td><td></td></tr><tr><td># data points</td><td>250</td><td></td></tr><tr><td># variables</td><td>6</td><td></td></tr><tr><td>chi-square</td><td> 0.01738249</td><td></td></tr><tr><td>reduced chi-square</td><td> 7.1240e-05</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2381.43814</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2360.30937</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> g1_amplitude </td><td>  0.47017934 </td><td>  0.00366353 </td><td> (0.78%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g1_center </td><td>  9.2896e-04 </td><td>  0.00162033 </td><td> (174.42%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g1_sigma </td><td>  0.19905213 </td><td>  0.00118273 </td><td> (0.59%) </td><td> 0.2 </td><td>  0.00000000 </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g1_fwhm </td><td>  0.46873194 </td><td>  0.00278512 </td><td> (0.59%) </td><td> 0.47096400000000005 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 2.3548200*g1_sigma </td></tr><tr><td> g1_height </td><td>  0.94233819 </td><td>  0.00318930 </td><td> (0.34%) </td><td> 1.9947115 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 0.3989423*g1_amplitude/max(2.220446049250313e-16, g1_sigma) </td></tr><tr><td> g2_amplitude </td><td>  0.46951545 </td><td>  0.00366505 </td><td> (0.78%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g2_center </td><td> -0.49937864 </td><td>  0.00163288 </td><td> (0.33%) </td><td> -0.3 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g2_sigma </td><td>  0.19970855 </td><td>  0.00119382 </td><td> (0.60%) </td><td> 0.2 </td><td>  0.00000000 </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> g2_fwhm </td><td>  0.47027769 </td><td>  0.00281123 </td><td> (0.60%) </td><td> 0.47096400000000005 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 2.3548200*g2_sigma </td></tr><tr><td> g2_height </td><td>  0.93791464 </td><td>  0.00316524 </td><td> (0.34%) </td><td> 1.9947115 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 0.3989423*g2_amplitude/max(2.220446049250313e-16, g2_sigma) </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>g1_amplitude</td><td>g2_amplitude</td><td>-0.9355</td></tr><tr><td>g1_amplitude</td><td>g2_center</td><td>-0.9235</td></tr><tr><td>g1_center</td><td>g2_amplitude</td><td>0.9232</td></tr><tr><td>g1_center</td><td>g2_center</td><td>0.9156</td></tr><tr><td>g2_amplitude</td><td>g2_sigma</td><td>0.9138</td></tr><tr><td>g1_amplitude</td><td>g1_sigma</td><td>0.9133</td></tr><tr><td>g2_amplitude</td><td>g2_center</td><td>0.9001</td></tr><tr><td>g1_amplitude</td><td>g1_center</td><td>-0.9000</td></tr><tr><td>g1_amplitude</td><td>g2_sigma</td><td>-0.8594</td></tr><tr><td>g1_sigma</td><td>g2_amplitude</td><td>-0.8585</td></tr><tr><td>g1_center</td><td>g2_sigma</td><td>0.8497</td></tr><tr><td>g1_sigma</td><td>g2_center</td><td>-0.8493</td></tr><tr><td>g2_center</td><td>g2_sigma</td><td>0.8256</td></tr><tr><td>g1_center</td><td>g1_sigma</td><td>-0.8248</td></tr><tr><td>g1_sigma</td><td>g2_sigma</td><td>-0.7202</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(12,9))
testHist2.errorbar()
# testHist2.fitBreitWigner()
# testHist2.fitSplitLorentzian()
testHist2.fitDonaich()
# testHist2.fitSkewedVoigt()
# Out:
# <h2> Model</h2> Model(doniach) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>53</td><td></td></tr><tr><td># data points</td><td>250</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 0.44288963</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.00180036</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1575.97390</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1561.88806</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> amplitude </td><td>  0.19596010 </td><td>  0.00269395 </td><td> (1.37%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> center </td><td>  0.17616197 </td><td>  0.00353757 </td><td> (2.01%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> sigma </td><td>  0.20971812 </td><td>  0.00475031 </td><td> (2.27%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> gamma </td><td> -0.07170879 </td><td>  0.00810750 </td><td> (11.31%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> height </td><td>  1.03852129 </td><td>  0.01385309 </td><td> (1.33%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> False </td><td> amplitude/max(2.220446049250313e-16, (sigma**(1-gamma)))*cos(pi*gamma/2) </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>center</td><td>gamma</td><td>0.7048</td></tr><tr><td>sigma</td><td>gamma</td><td>-0.6325</td></tr><tr><td>amplitude</td><td>sigma</td><td>0.5878</td></tr><tr><td>center</td><td>sigma</td><td>-0.4457</td></tr></table>
